# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df_unicorns = pd.read_csv('unicorns.csv')

# %%
df_unicorns
# Out:
#                   Company  Valuation ($B) Date Joined        Country  \
# 0               ByteDance           140.0  2017-04-07          China
# 1                  SpaceX           127.0  2012-12-01  United States
# 2                   SHEIN           100.0  2018-07-03          China
# 3                  Stripe            95.0  2014-01-23  United States
# 4                   Canva            40.0  2018-01-08      Australia
# ...                   ...             ...         ...            ...
# 1181          LeadSquared             1.0  2022-06-21          India
# 1182            FourKites             1.0  2022-06-21  United States
# 1183          VulcanForms             1.0  2022-07-05  United States
# 1184          SingleStore             1.0  2022-07-12  United States
# 1185  Unstoppable Domains             1.0  2022-07-27  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# 1         Hawthorne                                Other
# 2          Shenzhen      E-commerce & direct-to-consumer
# 3     San Francisco                              Fintech
# 4       Surry Hills         Internet software & services
# ...             ...                                  ...
# 1181      Bengaluru         Internet software & services
# 1182        Chicago  Supply chain, logistics, & delivery
# 1183     Burlington  Supply chain, logistics, & delivery
# 1184  San Francisco          Data management & analytics
# 1185      Las Vegas         Internet software & services
#
#                                               Investors  Month  Year
# 0     Sequoia Capital China, SIG Asia Investments, S...      4  2017
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...     12  2012
# 2     Tiger Global Management, Sequoia Capital China...      7  2018
# 3           Khosla Ventures, LowercaseCapital, capitalG      1  2014
# 4     Sequoia Capital China, Blackbird Ventures, Mat...      1  2018
# ...                                                 ...    ...   ...
# 1181  Gaja Capital Partners, Stakeboat Capital, West...      6  2022
# 1182  Hyde Park Venture Partners, Bain Capital Ventu...      6  2022
# 1183  Eclipse Ventures, D1 Capital Partners, Industr...      7  2022
# 1184            Google Ventures, Accel, Data Collective      7  2022
# 1185              Boost VC, Draper Associates, Gaingels      7  2022
#
# [1186 rows x 9 columns]

# %% [markdown]
# # Create dashboard with panel library

# %%
# Make dataframe Pipeline Interactive
idf_unicorns = df_unicorns.interactive()

# %% [markdown]
# ## Viz 1

# %%
# Define Panel Widgets
countries = df_unicorns['Country'].unique().tolist()
select_countries = pn.widgets.Select(
    name='Select Country', options=countries)

# %%
viz1_pipeline =(
    idf_unicorns[
        (idf_unicorns.Country == select_countries)
    ]
    .groupby(['Year', 'Country'])['Company'].count()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

# %%
viz1_pipeline
# Out:
# <div id='1683'>
#   <div class="bk-root" id="325062aa-7a0f-458a-8d8b-40537e05ebab" data-root-id="1683"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"7fee1c0f-fbba-404d-8679-a895e91c230d":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1687"}],"margin":[0,0,0,0],"name":"Column04562"},"id":"1686","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame04587","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Company&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;2014&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;1&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;2015&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;19&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;2016&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;12&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;2017&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;19&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;2018&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;37&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;5&lt;/th&gt;\n      &lt;td&gt;2019&lt;/td&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;23 ...
#     var render_items = [{"docid":"7fee1c0f-fbba-404d-8679-a895e91c230d","root_ids":["1683"],"roots":{"1683":"325062aa-7a0f-458a-8d8b-40537e05ebab"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
viz1_plot = viz1_pipeline.hvplot(x='Year', by='Country', y='Company', title='Number of companies created over the years')
viz1_plot
# Out:
# <div id='1692'>
#   <div class="bk-root" id="7fdd14de-203a-46f3-b97c-3afc7ceaf4d0" data-root-id="1692"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"86f0b931-7a8b-4296-b04a-9201fcb74a67":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"overlay":{"id":"1723"}},"id":"1721","type":"BoxZoomTool"},{"attributes":{},"id":"1718","type":"SaveTool"},{"attributes":{},"id":"1722","type":"ResetTool"},{"attributes":{"end":48.3,"reset_end":48.3,"reset_start":-3.3,"start":-3.3,"tags":[[["Company","Company",null]]]},"id":"1699","type":"Range1d"},{"attributes":{"line_alpha":0.1,"line_color":"#30a2da","line_width":2,"x":{"field":"Year"},"y":{"field":"Company"}},"id":"1741","type":"Line"},{"attributes":{},"id":"1732","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"1694"},{"id":"1701"}],"margin":[0,0,0,0],"name":"Column04734"},"id":"1693","type":"Column"},{"attributes":{"below":[{"id":"1710"}],"center":[{"id":"1713"},{"id":"1717"}],"height":300,"left":[{"id":"1714"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"1743"}],"right":[{"id":"1755"}],"sizing_mode":"fixed","title":{"id":"1702"},"toolbar":{"id":"1724"},"width":700,"x_range":{"id":"1698"},"x_scale":{"id":"1706"},"y_range":{"id":"1699"},"y_scale":{"id":"1708"}},"id":"1701","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1733","type":"AllLabels"},{"attributes":{},"id":"1711","type":"BasicTicker"},{"attributes":{"coordinates":null,"group":null,"text":"Number of companies created over the years","text_color":"black","text_font_size":"12pt"},"id":"1702","type":"Title"},{"attributes":{"axis_label":"Year ...

# %% [markdown]
# ## Viz 2

# %%
viz2_table = viz1_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
viz2_table
# Out:
# <div id='1849'>
#   <div class="bk-root" id="632a6896-5619-4d80-8929-96f37a5119fc" data-root-id="1849"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"d127ac22-b86d-4ba6-939b-24aec1542577":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"1870","type":"StringEditor"},{"attributes":{"children":[{"id":"1850"}],"margin":[0,0,0,0],"name":"Row04967"},"id":"1849","type":"Row"},{"attributes":{"children":[{"id":"1852"},{"id":"1854"}],"margin":[0,0,0,0],"name":"Row04965"},"id":"1851","type":"Row"},{"attributes":{"editor":{"id":"1860"},"field":"index","formatter":{"id":"1858"},"title":"index","width":0},"id":"1861","type":"TableColumn"},{"attributes":{"editor":{"id":"1870"},"field":"Country","formatter":{"id":"1869"},"title":"Country","width":0},"id":"1871","type":"TableColumn"},{"attributes":{"children":[{"id":"1851"},{"id":"1855"}],"margin":[0,0,0,0],"name":"Column04966"},"id":"1850","type":"Column"},{"attributes":{"children":[{"id":"1853"}],"margin":[0,0,0,0],"name":"Column04938"},"id":"1852","type":"Column"},{"attributes":{"text_align":"left"},"id":"1858","type":"NumberFormatter"},{"attributes":{},"id":"1860","type":"CellEditor"},{"attributes":{},"id":"1881","type":"UnionRenderers"},{"attributes":{"client_comm_id":"f1f67e9177784ef48a2c69eca25c8d28","comm_id":"77c07dc77db64e33873a69e2ee0d19c0","plot_id":"1849"},"id":"1887","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer04964","sizing_mode":"stretch_width"},"id":"1854","type":"Spacer"},{"attributes":{"text_align":"right"},"id":"1874","type":"NumberFormatter"},{"attributes":{},"id":"1875","type":"IntEditor"},{"attributes":{"children":[{"id" ...
#     var render_items = [{"docid":"d127ac22-b86d-4ba6-939b-24aec1542577","root_ids":["1849"],"roots":{"1849":"632a6896-5619-4d80-8929-96f37a5119fc"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined) && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## Viz3

# %%
industries = df_unicorns['Industry'].unique().tolist()
viz3_pipeline = (
    idf_unicorns[
        (idf_unicorns.Country == select_countries) &
        (idf_unicorns.Industry.isin(industries))
    ]
    .groupby(['Country', 'Industry'])['Valuation ($B)'].mean()
    .to_frame()
    .reset_index()
)

# %%
viz3_pipeline
# Out:
# <div id='1898'>
#   <div class="bk-root" id="e48a9a9b-36be-4108-9467-54642444d77f" data-root-id="1898"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"23314266-e301-4a4e-9e41-08fee24730f7":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1905"}],"margin":[0,0,0,0],"name":"Row05468"},"id":"1904","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame05491","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Industry&lt;/th&gt;\n      &lt;th&gt;Valuation ($B)&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;Artificial Intelligence&lt;/td&gt;\n      &lt;td&gt;1.240000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;Artificial intelligence&lt;/td&gt;\n      &lt;td&gt;11.146667&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;Auto &amp;amp; transportation&lt;/td&gt;\n      &lt;td&gt;3.379474&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;Consumer &amp;amp; retail&lt;/td&gt;\n      &lt;td&gt;4.770000&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;4&lt;/th&gt;\n      &lt;td&gt;China&lt;/td&gt;\n      &lt;td&gt;Cybersecurity&lt;/td&gt;\n      &lt;td&gt;1.320000&lt;/td&gt;\n    &lt;/tr&gt;\n  ...
#     var render_items = [{"docid":"23314266-e301-4a4e-9e41-08fee24730f7","root_ids":["1898"],"roots":{"1898":"e48a9a9b-36be-4108-9467-54642444d77f"}}];
#     root.

# %%
viz3_scatterplot = viz3_pipeline.hvplot(x='Valuation ($B)', y='Industry', by='Country', size=80, kind='scatter', legend=False,
                                        height=500, width=500, title='Average Valuation by industry')

# %%
viz3_scatterplot
# Out:
# <div id='1907'>
#   <div class="bk-root" id="a2629430-33b2-4ed7-aeaf-73b2302e66d3" data-root-id="1907"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"dbd28c54-2a0b-4742-be87-c86a751035a0":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"1924","type":"CategoricalScale"},{"attributes":{},"id":"1922","type":"LinearScale"},{"attributes":{},"id":"1927","type":"BasicTicker"},{"attributes":{"callback":null,"renderers":[{"id":"1958"}],"tags":["hv_created"],"tooltips":[["Country","@{Country}"],["Valuation ($B)","@{Valuation_left_parenthesis_B_right_parenthesis}"],["Industry","@{Industry}"]]},"id":"1916","type":"HoverTool"},{"attributes":{},"id":"1947","type":"BasicTickFormatter"},{"attributes":{"margin":[5,10,5,10],"options":["China","United States","Australia","United Kingdom","Bahamas","India","Indonesia","Germany","Turkey","Hong Kong","Seychelles","Sweden","Mexico","Estonia","Canada","Netherlands","France","Israel","Finland","Colombia","Belgium","Brazil","South Korea","Denmark","Switzerland","Lithuania","Austria","Ireland","Singapore","Vietnam","United Arab Emirates","Argentina","Spain","Japan","Luxembourg","Nigeria","Philippines","Croatia","Senegal","Malaysia","Bermuda","Norway","South Africa","Ecuador","Chile","Thailand","Czech Republic","Italy"],"title":"Select Country","value":"China"},"id":"1911","type":"panel.models.widgets.CustomSelect"},{"attributes":{},"id":"1948","type":"AllLabels"},{"attributes":{"below":[{"id":"1926"}],"center":[{"id":"1929"},{"id":"1932"}],"height":500,"left":[{"id":"1930"}],"margin":[5,5,5,5],"min_border_bottom":10,"min_border_left":10,"min_border_right":10,"min_border_top":10,"renderers":[{"id":"1958"}] ...

# %% [markdown]
# ## Viz4

# %%
viz4_pipeline = (
    idf_unicorns[
        (idf_unicorns.Country == select_countries) &
        (idf_unicorns.Industry.isin(industries))
    ]
    .groupby(['Country', 'Industry'])['Company'].count()
    .to_frame()
    .reset_index()
)

# %%
viz4_pipeline
# Out:
# <div id='2052'>
#   <div class="bk-root" id="04e50f2c-3613-4f3b-8bb2-743ad7ac2f56" data-root-id="2052"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"cfa01b22-6bf8-4c0c-9cc6-03a4035bf425":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"2056"}],"margin":[0,0,0,0],"name":"Column06290"},"id":"2055","type":"Column"},{"attributes":{"children":[{"id":"2059"}],"margin":[0,0,0,0],"name":"Row06295"},"id":"2058","type":"Row"},{"attributes":{"children":[{"id":"2054"},{"id":"2058"}],"margin":[0,0,0,0],"name":"Column06322"},"id":"2053","type":"Column"},{"attributes":{"margin":[5,10,5,10],"options":["China","United States","Australia","United Kingdom","Bahamas","India","Indonesia","Germany","Turkey","Hong Kong","Seychelles","Sweden","Mexico","Estonia","Canada","Netherlands","France","Israel","Finland","Colombia","Belgium","Brazil","South Korea","Denmark","Switzerland","Lithuania","Austria","Ireland","Singapore","Vietnam","United Arab Emirates","Argentina","Spain","Japan","Luxembourg","Nigeria","Philippines","Croatia","Senegal","Malaysia","Bermuda","Norway","South Africa","Ecuador","Chile","Thailand","Czech Republic","Italy"],"title":"Select Country","value":"China"},"id":"2056","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"2053"}],"margin":[0,0,0,0],"name":"Row06323"},"id":"2052","type":"Row"},{"attributes":{"children":[{"id":"2055"},{"id":"2057"}],"margin":[0,0,0,0],"name":"Row06321"},"id":"2054","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer06320","sizing_mode":"stretch_width"},"id":"2057","type":"Spacer"},{"attributes":{"client_comm_id":"29601b2ca9db4c9fa067c7f3bd24ba29","comm_id ...
#     var render_items = [{"docid":"cfa01b22-6bf8-4c0c-9cc6-03a4035bf425","root_ids":["2052"],"roots":{"2052":"04e50f2c-3613-4f3b-8bb2-743ad7ac2f56"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Pan

# %%
viz4_barplot = viz4_pipeline.hvplot(kind='barh', x='Industry', y='Company', title='Amount os unicorns by industries')
viz4_barplot
# Out:
# <div id='2061'>
#   <div class="bk-root" id="240de793-51e5-4dc1-ae9b-05d8bee1f0df" data-root-id="2061"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f19fa98c-da73-41f7-afa3-8b5e679ef0ee":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"coordinates":null,"group":null,"text":"Amount os unicorns by industries","text_color":"black","text_font_size":"12pt"},"id":"2072","type":"Title"},{"attributes":{},"id":"2114","type":"AllLabels"},{"attributes":{},"id":"2088","type":"PanTool"},{"attributes":{},"id":"2122","type":"UnionRenderers"},{"attributes":{},"id":"2089","type":"WheelZoomTool"},{"attributes":{"axis":{"id":"2080"},"coordinates":null,"grid_line_color":null,"group":null,"ticker":null},"id":"2083","type":"Grid"},{"attributes":{},"id":"2081","type":"BasicTicker"},{"attributes":{"axis_label":"Industry","coordinates":null,"formatter":{"id":"2113"},"group":null,"major_label_policy":{"id":"2114"},"ticker":{"id":"2085"}},"id":"2084","type":"CategoricalAxis"},{"attributes":{"data":{"Company":[4,15,19,8,1,2,28,12,8,18,11,15,13,6,11,3],"Industry":["Artificial Intelligence","Artificial intelligence","Auto & transportation","Consumer & retail","Cybersecurity","Data management & analytics","E-commerce & direct-to-consumer","Edtech","Fintech","Hardware","Health","Internet software & services","Mobile & telecommunications","Other","Supply chain, logistics, & delivery","Travel"]},"selected":{"id":"2101"},"selection_policy":{"id":"2122"}},"id":"2100","type":"ColumnDataSource"},{"attributes":{},"id":"2113","type":"CategoricalTickFormatter"},{"attributes":{"axis":{"id":"2084"},"coordinates":null,"dimension":1,"grid_line_color":null,"group":null,"ticker":n ...

# %% [markdown]
# ## Creating Dashboard

# %%
# Layout using Template
template = pn.template.FastListTemplate(
    title='Rise of unicorns between 2014 and 2022',
    sidebar=[pn.pane.PNG('unicorn.png', height=100),
             pn.pane.Markdown('# Unicorns'),
             pn.pane.Markdown('#### In business, a unicorn is a privately held startup company valued at over US$1 billion. The term was first published in 2013, coined by venture capitalist Aileen Lee, choosing the mythical animal to represent the statistical rarity of such successful ventures.'),
             pn.pane.Markdown('## Settings'), select_countries],
    main=[pn.Row(pn.Column(viz1_plot.panel(width=700), margin=(0,25)), viz2_table.panel(width=500)),
          pn.Row(pn.Column(viz3_scatterplot.panel(width=600), margin=(0,25)), viz4_barplot.panel(width=600, height=500))],
    accent_base_color='#FFF6A3',
    header_background='#96BBDB'
)

# %%
#Template.show()
template.servable();
