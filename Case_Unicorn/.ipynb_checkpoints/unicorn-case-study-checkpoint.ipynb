# %% [markdown]
# # Descriptive Analysis 🦄
# It is a descriptive analysis of the dataset referring to unicorn companies for study purposes.
# Unicorns are startups with 1 billion dollars valuation.

# %% [markdown]
# ## ❓ Ask Phase
# Identify the growth of unicorn companies by year and in which countries there is a greater tendency for these companies to emerge.

# %% [markdown]
# ## Prepare Phase
# The data source used for this case study is [Unicorn Startups Data](https://www.kaggle.com/datasets/ramjasmaurya/unicorn-startups). This dataset is open-source and contains 1186 records.

# %% [markdown]
# ## Process Phase

# %%
# Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Create dataframe
df_unicorns = pd.read_csv("Dataset/unicorns_sep_2022.csv")
df_unicorns
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140    4/7/2017          China
# 1                  SpaceX           $127   12/1/2012  United States
# 2                   SHEIN           $100    7/3/2018          China
# 3                  Stripe            $95   1/23/2014  United States
# 4                   Canva            $40    1/8/2018      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1   6/21/2022          India
# 1182            FourKites             $1   6/21/2022  United States
# 1183          VulcanForms             $1    7/5/2022  United States
# 1184          SingleStore             $1   7/12/2022  United States
# 1185  Unstoppable Domains             $1   7/27/2022  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# 1         Hawthorne                                Other
# 2          Shenzhen      E-commerce & direct-to-consumer
# 3     San Francisco                              Fintech
# 4       Surry Hills         Internet software & services
# ...             ...                                  ...
# 1181      Bengaluru         Internet software & services
# 1182        Chicago  Supply chain, logistics, & delivery
# 1183     Burlington  Supply chain, logistics, & delivery
# 1184  San Francisco          Data management & analytics
# 1185      Las Vegas         Internet software & services
#
#                                               Investors
# 0     Sequoia Capital China, SIG Asia Investments, S...
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2     Tiger Global Management, Sequoia Capital China...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 4     Sequoia Capital China, Blackbird Ventures, Mat...
# ...                                                 ...
# 1181  Gaja Capital Partners, Stakeboat Capital, West...
# 1182  Hyde Park Venture Partners, Bain Capital Ventu...
# 1183  Eclipse Ventures, D1 Capital Partners, Industr...
# 1184            Google Ventures, Accel, Data Collective
# 1185              Boost VC, Draper Associates, Gaingels
#
# [1186 rows x 7 columns]

# %%
# Check dimension
df_unicorns.shape
# Out:
# (1186, 7)

# %%
# check first records
df_unicorns.head()
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140    4/7/2017          China        Beijing
# 1     SpaceX           $127   12/1/2012  United States      Hawthorne
# 2      SHEIN           $100    7/3/2018          China       Shenzhen
# 3     Stripe            $95   1/23/2014  United States  San Francisco
# 4      Canva            $40    1/8/2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
# General dataframe information
df_unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1186 non-null   object
#  1   Valuation ($B)  1186 non-null   object
#  2   Date Joined     1186 non-null   object
#  3   Country         1186 non-null   object
#  4   City            1186 non-null   object
#  5   Industry        1186 non-null   object
#  6   Investors       1168 non-null   object
# dtypes: object(7)
# memory usage: 65.0+ KB

# %%
df_unicorns.describe()
# Out:
#        Company Valuation ($B) Date Joined        Country          City   \
# count     1186           1186        1186           1186           1186
# unique    1183            222         695             48            286
# top       Bolt             $1   7/13/2021  United States  San Francisco
# freq         2            271           9            636            168
#
#        Industry        Investors
# count      1186             1168
# unique       34             1152
# top     Fintech  Sequoia Capital
# freq        239                3

# %%
df_unicorns.nunique()
# Out:
# Company           1183
# Valuation ($B)     222
# Date Joined        695
# Country             48
# City               286
# Industry            34
# Investors         1152
# dtype: int64

# %%
# Check null values
df_unicorns.isnull().sum()

#It is not necessary to delete null records, as only the investor column has null records and this will not interfere with the analysis.
# Out:
# Company            0
# Valuation ($B)     0
# Date Joined        0
# Country            0
# City               0
# Industry           0
# Investors         18
# dtype: int64

# %%
# Check duplicate records
df_unicorns.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Analyse Phase and Share Phase

# %% [markdown]
# ### Ranking of the industries that generate the most unicorn companies
# In this analysis, we observed a greater number of Fintechs emerging, followed by software internet services.

# %%
industries = df_unicorns['Industry'].value_counts()
industries
# Out:
# Fintech                                                               239
# Internet software & services                                          224
# E-commerce & direct-to-consumer                                       103
# Health                                                                 94
# Artificial intelligence                                                74
# Supply chain, logistics, & delivery                                    65
# Other                                                                  65
# Cybersecurity                                                          58
# Data management & analytics                                            45
# Auto & transportation                                                  40
# Hardware                                                               38
# Mobile & telecommunications                                            37
# Edtech                                                                 32
# Consumer & retail                                                      28
# Travel                                                                 14
# Artificial Intelligence                                                11
# Internet                                                                2
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                  1
# Andreessen Horowitz, DST Global, IDG Capital                            1
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution      1
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures         1
# Mundi Ventures, Doqling Capital Partners, Activant Capital              1
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures                1
# Dragonfly Captial, Qiming Venture Partners, DST Global                  1
# Sequoia Capital China, Shunwei Capital Partners, Qualgro                1
# Tiger Global Management, Tiger Brokers, DCM Ventures                    1
# 500 Global, Rakuten Ventures, Golden Gate Ventures                      1
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures           1
# Vision Plus Capital, GSR Ventures, ZhenFund                             1
# GIC. Apis Partners, Insight Partners                                    1
# Jungle Ventures, Accel, Venture Highway                                 1
# Kuang-Chi                                                               1
# Sequoia Capital, Thoma Bravo, Softbank                                  1
# Temasek, Guggenheim Investments, Qatar Investment Authority             1
# Name: Industry, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.title('Industries Ranking', fontsize=20)
industry = df_unicorns.sort_values
plt.barh(industries.sort_values().index,industries.sort_values())
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# ### Ranking in percentage of the Countries that generate the most unicorn companies
# The United States is the country where the most unicorn companies appear.

# %%
countries = df_unicorns['Country'].value_counts()
countries10 = countries.head(10)
countries10
# Out:
# United States     636
# China             174
# India              70
# United Kingdom     46
# Germany            29
# France             24
# Israel             22
# Canada             19
# Brazil             17
# South Korea        17
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(14,6))
plt.title('Top 10 Countries Analysis', fontsize=20)
plt.bar(countries10.index,countries10)
plt.show()

# %%
# Convert column Date Joined to date
df_unicorns['Date Joined'] = pd.to_datetime(df_unicorns['Date Joined'])
df_unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1186 non-null   object
#  1   Valuation ($B)  1186 non-null   object
#  2   Date Joined     1186 non-null   datetime64[ns]
#  3   Country         1186 non-null   object
#  4   City            1186 non-null   object
#  5   Industry        1186 non-null   object
#  6   Investors       1168 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 65.0+ KB

# %%
# Extract year and month
df_unicorns['Month'] = pd.DatetimeIndex(df_unicorns['Date Joined']).month
df_unicorns['Year'] = pd.DatetimeIndex(df_unicorns['Date Joined']).year

df_unicorns.head()
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140  2017-04-07          China        Beijing
# 1     SpaceX           $127  2012-12-01  United States      Hawthorne
# 2      SHEIN           $100  2018-07-03          China       Shenzhen
# 3     Stripe            $95  2014-01-23  United States  San Francisco
# 4      Canva            $40  2018-01-08      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors  Month  Year
# 0  Sequoia Capital China, SIG Asia Investments, S...      4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...     12  2012
# 2  Tiger Global Management, Sequoia Capital China...      7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG      1  2014
# 4  Sequoia Capital China, Blackbird Ventures, Mat...      1  2018

# %% [markdown]
# ### Number of unicorn companies that have emerged over the years
# There was a high emergence of these companies in **2021**, the year the **pandemic** was still in effect, and most of them were **Fintechs**.

# %%
company_year = df_unicorns.groupby(by=['Year']).count()['Company'].reset_index()
company_year
# Out:
#     Year  Company
# 0   2007        1
# 1   2011        2
# 2   2012        4
# 3   2013        3
# 4   2014       12
# 5   2015       34
# 6   2016       21
# 7   2017       44
# 8   2018       98
# 9   2019      102
# 10  2020      108
# 11  2021      529
# 12  2022      228

# %%
plt.figure(figsize=(10,6))
plt.title('Number of Companies by Country', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Number of Companies', fontsize=15)
plt.plot(company_year['Year'], company_year['Company'], color='C9', marker='o')
x0 = 2021
y0 = company_year['Company'].max()
plt.plot(x0, y0, 'P', color='r', markersize=10)
plt.show()

# %%
# Startups that emerged in 2021 separated by their respective industry sector
unicorns2021 = df_unicorns.loc[df_unicorns['Year'] == 2021]
unicorns2021_group = unicorns2021.groupby('Industry').count()['Company'].sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(16,10))
plt.title('Industry x Company 2021', fontsize=20)
plt.bar(unicorns2021_group['Industry'], unicorns2021_group['Company'])
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Convert column Valuation to float
df_unicorns['Valuation ($B)'] = pd.to_numeric(df_unicorns['Valuation ($B)'].apply(lambda Linha: Linha.replace('$', '')))
df_unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         1186 non-null   object
#  1   Valuation ($B)  1186 non-null   float64
#  2   Date Joined     1186 non-null   datetime64[ns]
#  3   Country         1186 non-null   object
#  4   City            1186 non-null   object
#  5   Industry        1186 non-null   object
#  6   Investors       1168 non-null   object
#  7   Month           1186 non-null   int64
#  8   Year            1186 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 83.5+ KB

# %%
# Sum of the Valuation column by country
country_valuation = df_unicorns.groupby(by = ['Country']).sum()['Valuation ($B)'].sort_values(ascending=False).reset_index()
country_valuation
# Out:
#                  Country  Valuation ($B)
# 0          United States         2069.89
# 1                  China          678.59
# 2         United Kingdom          205.45
# 3                  India          202.92
# 4                Germany           80.88
# 5                 France           58.42
# 6              Australia           54.40
# 7                 Canada           49.23
# 8                 Israel           48.02
# 9                 Brazil           40.08
# 10           South Korea           34.13
# 11               Bahamas           32.00
# 12             Indonesia           29.13
# 13                Sweden           23.62
# 14           Netherlands           22.46
# 15             Singapore           20.75
# 16             Hong Kong           20.35
# 17                Mexico           18.70
# 18                Turkey           15.77
# 19               Finland           12.46
# 20           Switzerland           12.30
# 21               Ireland           10.05
# 22            Seychelles           10.00
# 23               Estonia            9.90
# 24               Belgium            8.95
# 25                 Japan            8.82
# 26               Austria            7.61
# 27              Colombia            7.40
# 28               Denmark            6.70
# 29                 Spain            6.15
# 30             Lithuania            6.13
# 31                Norway            5.70
# 32               Vietnam            5.27
# 33  United Arab Emirates            5.05
# 34           Philippines            3.00
# 35               Croatia            3.00
# 36          South Africa            2.59
# 37                 Chile            2.50
# 38              Thailand            2.50
# 39             Argentina            2.45
# 40               Nigeria            2.00
# 41            Luxembourg            2.00
# 42               Senegal            1.70
# 43              Malaysia            1.70
# 44               Bermuda            1.60
# 45               Ecuador            1.50
# 46        Czech Republic            1.20
# 47                 Italy            1.00

# %%
plt.figure(figsize=(14,6))
plt.title('Top 10 Highest Valuation Countries', fontsize=20)
plt.bar(country_valuation['Country'].head(10), country_valuation['Valuation ($B)'].head(10))
plt.show()

# %%
# Sum of the Valuation column by Year
year_valuation = df_unicorns.groupby(by = ['Year']).sum()['Valuation ($B)'].reset_index()
year_valuation
# Out:
#     Year  Valuation ($B)
# 0   2007            1.38
# 1   2011           12.40
# 2   2012          158.00
# 3   2013           10.00
# 4   2014          160.80
# 5   2015           91.85
# 6   2016           80.17
# 7   2017          282.45
# 8   2018          575.46
# 9   2019          456.26
# 10  2020          418.19
# 11  2021         1229.51
# 12  2022          379.55

# %%
plt.figure(figsize=(10,6))
plt.title('Valuation by Year', fontsize=20)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Valuation ($B)', fontsize=15)
plt.plot(year_valuation['Year'], year_valuation['Valuation ($B)'], color='g', marker='o')
plt.show()

# %% [markdown]
# # Create dashboard with panel library

# %%
# Make dataframe Pipeline Interactive
idf_unicorns = df_unicorns.interactive()

# %% [markdown]
# ## Viz 1

# %%
# Define Panel Widgets
countries = df_unicorns['Country'].unique().tolist()
select_countries = pn.widgets.Select(
    name='Select Country', options=countries)

# %%
viz1_pipeline =(
    idf_unicorns[
        (idf_unicorns.Country == select_countries)
    ]
    .groupby(['Year', 'Country'])['Company'].count()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

# %%
viz1_pipeline
# Out:
# <div id='2919'>
#   <div class="bk-root" id="9be79d40-b917-478f-aea4-f66db4e7bff7" data-root-id="2919"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"3819b7d4-6335-41c5-9a9a-19f54b2d3721":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"2920"}],"margin":[0,0,0,0],"name":"Row14644"},"id":"2919","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer14641","sizing_mode":"stretch_width"},"id":"2924","type":"Spacer"},{"attributes":{"children":[{"id":"2922"},{"id":"2924"}],"margin":[0,0,0,0],"name":"Row14642"},"id":"2921","type":"Row"},{"attributes":{"children":[{"id":"2926"}],"margin":[0,0,0,0],"name":"Row14619"},"id":"2925","type":"Row"},{"attributes":{"client_comm_id":"c118c801035642f6898838de0990b6cf","comm_id":"86398cc383b94dccafaf2283ac868ba3","plot_id":"2919"},"id":"2927","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,10,5,10],"options":["China","United States","Australia","United Kingdom","Bahamas","India","Indonesia","Germany","Turkey","Hong Kong","Seychelles","Sweden","Mexico","Estonia","Canada","Netherlands","France","Israel","Finland","Colombia","Belgium","Brazil","South Korea","Denmark","Switzerland","Lithuania","Austria","Ireland","Singapore","Vietnam","United Arab Emirates","Argentina","Spain","Japan","Luxembourg","Nigeria","Philippines","Croatia","Senegal","Malaysia","Bermuda","Norway","South Africa","Ecuador","Chile","Thailand","Czech Republic","Italy"],"title":"Select Country","value":"China"},"id":"2923","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"2921"},{"id":"2925"}],"margin":[0,0,0,0],"name":"Column14643"},"id":"2920","type":"Column ...
#     var render_items = [{"docid":"3819b7d4-6335-41c5-9a9a-19f54b2d3721","root_ids":["2919"],"roots":{"2919":"9be79d40-b917-478f-aea4-f66db4e7bff7"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
viz1_plot = viz1_pipeline.hvplot(x='Year', by='Country', y='Company')
viz1_plot
# Out:
# <div id='2928'>
#   <div class="bk-root" id="6413dbc8-5c9b-448e-9756-8e51bace8887" data-root-id="2928"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"e0fc4bdb-72af-4566-864f-5330173b40c0":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"end":2022.0,"reset_end":2022.0,"reset_start":2014.0,"start":2014.0,"tags":[[["Year","Year",null]]]},"id":"2934","type":"Range1d"},{"attributes":{"line_color":"#30a2da","line_width":2,"x":{"field":"Year"},"y":{"field":"Company"}},"id":"2993","type":"Line"},{"attributes":{},"id":"2988","type":"UnionRenderers"},{"attributes":{"margin":[5,10,5,10],"options":["China","United States","Australia","United Kingdom","Bahamas","India","Indonesia","Germany","Turkey","Hong Kong","Seychelles","Sweden","Mexico","Estonia","Canada","Netherlands","France","Israel","Finland","Colombia","Belgium","Brazil","South Korea","Denmark","Switzerland","Lithuania","Austria","Ireland","Singapore","Vietnam","United Arab Emirates","Argentina","Spain","Japan","Luxembourg","Nigeria","Philippines","Croatia","Senegal","Malaysia","Bermuda","Norway","South Africa","Ecuador","Chile","Thailand","Czech Republic","Italy"],"title":"Select Country","value":"China"},"id":"2932","type":"panel.models.widgets.CustomSelect"},{"attributes":{"callback":null,"renderers":[{"id":"2979"}],"tags":["hv_created"],"tooltips":[["Country","@{Country}"],["Year","@{Year}"],["Company","@{Company}"]]},"id":"2936","type":"HoverTool"},{"attributes":{"overlay":{"id":"2959"}},"id":"2957","type":"BoxZoomTool"},{"attributes":{},"id":"2968","type":"BasicTickFormatter"},{"attributes":{"coordinates":null,"data_source":{"id":"2973"},"glyph":{"id":"2976"},"group":null,"hover_gly ...

# %% [markdown]
# ## Viz 2

# %%
viz2_table = viz1_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')
viz2_table
# Out:
# <div id='3085'>
#   <div class="bk-root" id="0ad04e25-63e2-4505-beb2-8caca004e355" data-root-id="3085"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"bd92f9fe-e41c-4cf7-aa6a-e19816ec3708":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"editor":{"id":"3106"},"field":"Country","formatter":{"id":"3105"},"title":"Country","width":0},"id":"3107","type":"TableColumn"},{"attributes":{"children":[{"id":"3086"}],"margin":[0,0,0,0],"name":"Row15076"},"id":"3085","type":"Row"},{"attributes":{},"id":"3106","type":"StringEditor"},{"attributes":{},"id":"3105","type":"StringFormatter"},{"attributes":{},"id":"3101","type":"IntEditor"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer15073","sizing_mode":"stretch_width"},"id":"3090","type":"Spacer"},{"attributes":{"children":[{"id":"3115"}],"margin":[0,0,0,0],"name":"Row15052"},"id":"3091","type":"Row"},{"attributes":{"data":{"Company":[1,19,12,19,37,23,11,44,8],"Country":["China","China","China","China","China","China","China","China","China"],"Year":[2014,2015,2016,2017,2018,2019,2020,2021,2022],"index":[0,1,2,3,4,5,6,7,8]},"selected":{"id":"3093"},"selection_policy":{"id":"3117"}},"id":"3092","type":"ColumnDataSource"},{"attributes":{"editor":{"id":"3101"},"field":"Year","formatter":{"id":"3100"},"title":"Year","width":0},"id":"3102","type":"TableColumn"},{"attributes":{"margin":[5,10,5,10],"options":["China","United States","Australia","United Kingdom","Bahamas","India","Indonesia","Germany","Turkey","Hong Kong","Seychelles","Sweden","Mexico","Estonia","Canada","Netherlands","France","Israel","Finland","Colombia","Belgium","Brazil","South Korea","Denmark","Switzerland","Lithuania","Austria","Irela ...
#     var render_items = [{"docid":"bd92f9fe-e41c-4cf7-aa6a-e19816ec3708","root_ids":["3085"],"roots":{"3085":"0ad04e25-63e2-4505-beb2-8caca004e355"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## Viz3

# %%
industries = df_unicorns['Industry'].unique().tolist()
viz3_pipeline = (
    idf_unicorns[
        (idf_unicorns.Country == select_countries) &
        (idf_unicorns.Industry.isin(industries))
    ]
    .groupby(['Country', 'Industry'])['Valuation ($B)'].mean()
    .to_frame()
    .reset_index()
)

# %%
viz3_pipeline
# Out:
# <div id='29799'>
#   <div class="bk-root" id="74a95cd4-36fc-485f-8985-6797f4125ade" data-root-id="29799"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"76cf772f-0741-44dc-83d9-7542fd5ae532":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"client_comm_id":"29407aa298494cb4b04ca5d710ba45f2","comm_id":"ac18b56a28694191a188473fcebb70e1","plot_id":"29799"},"id":"29807","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"29802"},{"id":"29804"}],"margin":[0,0,0,0],"name":"Row70010"},"id":"29801","type":"Row"},{"attributes":{"children":[{"id":"29806"}],"margin":[0,0,0,0],"name":"Row69984"},"id":"29805","type":"Row"},{"attributes":{"children":[{"id":"29803"}],"margin":[0,0,0,0],"name":"Column69979"},"id":"29802","type":"Column"},{"attributes":{"children":[{"id":"29800"}],"margin":[0,0,0,0],"name":"Row70012"},"id":"29799","type":"Row"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame70007","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Industry&lt;/th&gt;\n      &lt;th&gt;Valuation ($B)&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;United States&lt;/td&gt;\n      &lt;td&gt;Artificial Intelligence&lt;/td&gt;\n      &lt;td&gt;1.457143&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;United States&lt;/td&gt;\n      &lt;td&gt;Artificial intelligence&lt;/td&gt;\n      &lt;td&gt;2.829111&lt;/td&gt;\n    &lt;/tr&gt;\n    ...

# %%
viz3_scatterplot = viz3_pipeline.hvplot(x='Valuation ($B)', y='Industry', by='Country', size=80, kind='scatter', legend=False,
                                        height=500, width=500)

# %%
viz3_scatterplot
# Out:
# <div id='29808'>
#   <div class="bk-root" id="c5032b14-cef5-40af-b308-9013f970fdb1" data-root-id="29808"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"1b189224-50af-417e-8933-c34b048dd79a":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"29834","type":"SaveTool"},{"attributes":{"client_comm_id":"1e66e7c65a5340af91151cb43fdea786","comm_id":"beba71992bf1437d952f3eeb84a9296f","plot_id":"29808"},"id":"29902","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"29811"},{"id":"29813"}],"margin":[0,0,0,0],"name":"Row70273"},"id":"29810","type":"Row"},{"attributes":{"overlay":{"id":"29839"}},"id":"29837","type":"BoxZoomTool"},{"attributes":{},"id":"29851","type":"CategoricalTickFormatter"},{"attributes":{},"id":"29838","type":"ResetTool"},{"attributes":{},"id":"29852","type":"AllLabels"},{"attributes":{"data":{"Country":["United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],"Industry":["Artificial Intelligence","Artificial intelligence","Auto & transportation","Consumer & retail","Cybersecurity","Data management & analytics","E-commerce & direct-to-consumer","Edtech","Fintech","Hardware","Health","Internet software & services","Mobile & telecommunications","Other","Supply chain, logistics, & delivery","Travel"],"Valuation ($B)":{"__ndarray__":"B3VQB3VQ9z+Rx5cBBaIGQKrx0k1iEAhAGWDOsvlnBEC511xImlIDQO1Fc+JuzwlAVmqlVmqlC0Acx3Ecx3ECQG8VwutWIQ5ADhaUdHz6AEBw+vhHnmkEQJSi6sB6bQdAkML1KFyPB0DaDUF0p9oaQHHOiNLe4A9AAAAAAAAAH ...

# %% [markdown]
# ## Viz4

# %%
viz4_pipeline = (
    idf_unicorns[
        (idf_unicorns.Country == select_countries) &
        (idf_unicorns.Industry.isin(industries))
    ]
    .groupby(['Country', 'Industry'])['Company'].count()
    .to_frame()
    .reset_index()
)

# %%
viz4_pipeline
# Out:
# <div id='32077'>
#   <div class="bk-root" id="d44dffd9-cfa1-4192-aa2a-ee01ae285a77" data-root-id="32077"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"94b9f09d-9c15-4797-86ea-95564d73baaa":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"client_comm_id":"a042cb4e8d7145bfaf6a48de15f2ea93","comm_id":"a0095a691c5c4399bc47c20b5ba99193","plot_id":"32077"},"id":"32085","type":"panel.models.comm_manager.CommManager"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer75051","sizing_mode":"stretch_width"},"id":"32082","type":"Spacer"},{"attributes":{"margin":[5,5,5,5],"name":"DataFrame75049","text":"&lt;table border=&quot;0&quot; class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Industry&lt;/th&gt;\n      &lt;th&gt;Company&lt;/th&gt;\n    &lt;/tr&gt;\n  &lt;/thead&gt;\n  &lt;tbody&gt;\n    &lt;tr&gt;\n      &lt;th&gt;0&lt;/th&gt;\n      &lt;td&gt;United Kingdom&lt;/td&gt;\n      &lt;td&gt;Artificial intelligence&lt;/td&gt;\n      &lt;td&gt;2&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;1&lt;/th&gt;\n      &lt;td&gt;United Kingdom&lt;/td&gt;\n      &lt;td&gt;Auto &amp;amp; transportation&lt;/td&gt;\n      &lt;td&gt;1&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;2&lt;/th&gt;\n      &lt;td&gt;United Kingdom&lt;/td&gt;\n      &lt;td&gt;Consumer &amp;amp; retail&lt;/td&gt;\n      &lt;td&gt;1&lt;/td&gt;\n    &lt;/tr&gt;\n    &lt;tr&gt;\n      &lt;th&gt;3&lt;/th&gt;\n      &lt;td&gt;United Kingdom&lt;/td&gt;\n      &lt;td&gt;Data management &amp;amp; analytics&lt;/td&gt;\n      &lt ...
#     var render_items = [{"docid":"94b9f09d-9c15-4797-86ea-95564d73baaa","root_ids":["32077"],"roots":{"32077":"d44dffd9-cfa1-4192-aa2a-ee01ae285a77"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "

# %%
viz4_barplot = viz4_pipeline.hvplot(kind='barh', x='Industry', y='Company', title='Amount os unicorns by industries')
viz4_barplot
# Out:
# <div id='32100'>
#   <div class="bk-root" id="ab61cc39-f330-4064-9244-e8f44cffb647" data-root-id="32100"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"b662f912-d730-49b6-bc4d-6c7e55ebf842":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{},"id":"32120","type":"BasicTicker"},{"attributes":{},"id":"32140","type":"Selection"},{"attributes":{},"id":"32124","type":"CategoricalTicker"},{"attributes":{"tools":[{"id":"32109"},{"id":"32126"},{"id":"32127"},{"id":"32128"},{"id":"32129"},{"id":"32130"}]},"id":"32132","type":"Toolbar"},{"attributes":{"end":29.6,"reset_end":29.6,"reset_start":0.0,"tags":[[["Company","Company",null]]]},"id":"32107","type":"Range1d"},{"attributes":{"children":[{"id":"32101"}],"margin":[0,0,0,0],"name":"Row75887"},"id":"32100","type":"Row"},{"attributes":{"bottom_units":"screen","coordinates":null,"fill_alpha":0.5,"fill_color":"lightgrey","group":null,"left_units":"screen","level":"overlay","line_alpha":1.0,"line_color":"black","line_dash":[4,4],"line_width":2,"right_units":"screen","syncable":false,"top_units":"screen"},"id":"32131","type":"BoxAnnotation"},{"attributes":{"axis":{"id":"32119"},"coordinates":null,"grid_line_color":null,"group":null,"ticker":null},"id":"32122","type":"Grid"},{"attributes":{"coordinates":null,"group":null,"text":"Amount os unicorns by industries","text_color":"black","text_font_size":"12pt"},"id":"32111","type":"Title"},{"attributes":{"callback":null,"renderers":[{"id":"32145"}],"tags":["hv_created"],"tooltips":[["Industry","@{Industry}"],["Company","@{Company}"]]},"id":"32109","type":"HoverTool"},{"attributes":{},"id":"32115","type":"LinearScale"},{"attributes":{},"id":"32117","type":"Cat ...
